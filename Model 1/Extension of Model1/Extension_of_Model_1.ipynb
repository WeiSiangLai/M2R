# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 1000)
y = np.exp(6-x) -1

plt.plot(x, y)
plt.xlabel('$Fa/k_BT$')
plt.ylabel('$v/ak_-$')
plt.title('Plot of $v/ak_-$ as a function of $Fa/k_BT$ for $\Delta G/k_BT = 6$')
plt.grid()
